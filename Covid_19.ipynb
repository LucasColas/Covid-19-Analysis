# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasColas/Covid-19-Analysis/blob/master/Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdf5c42c-3f09-425c-9cdd-9746ce3492f3" name="files[]" multiple disabled />
#      <output id="result-bdf5c42c-3f09-425c-9cdd-9746ce3492f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.xlsx to covid (1).xlsx

# %%
data = pd.read_excel(io.BytesIO(uploaded['covid.xlsx']))

# %%
pd.set_option('display.max_column', 111)
pd.set_option('display.max_row', 44)

# %%
data
# Out:
#            Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0     44477f75e8169d2                    13               negative
# 1     126e9dd13932f68                    17               negative
# 2     a46b4402a0e5696                     8               negative
# 3     f7d619a94f97c45                     5               negative
# 4     d9e41465789c2b5                    15               negative
# ...               ...                   ...                    ...
# 5639  ae66feb9e4dc3a0                     3               positive
# 5640  517c2834024f3ea                    17               negative
# 5641  5c57d6037fe266d                     4               negative
# 5642  c20c44766f28291                    10               negative
# 5643  2697fdccbfeb7f7                    19               positive
#
#       Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                                  0
# ...

# %%
df = data.copy()

# %%
df.shape
# Out:
# (5644, 111)

# %%
df.dtypes.value_counts().plot.pie()

# %%
df.dtypes.value_counts()
# Out:
# float64    70
# object     37
# int64       4
# dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.isna(), cbar=False)

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending = True)
# Out:
# Patient ID                                               0.0
# Patient age quantile                                     0.0
# SARS-Cov-2 exam result                                   0.0
# Patient addmited to regular ward (1=yes, 0=no)           0.0
# Patient addmited to semi-intensive unit (1=yes, 0=no)    0.0
#                                                         ...
# Partial thromboplastin time (PTT)                        1.0
# Urine - Sugar                                            1.0
# Mycoplasma pneumoniae                                    1.0
# D-Dimer                                                  1.0
# Prothrombin time (PT), Activity                          1.0
# Length: 111, dtype: float64

# %%
df = df[df.columns[df.isna().sum()/df.shape[0] < 0.90]]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isna(), cbar=False)

# %%
df = df.drop('Patient ID', axis=1)

# %%
df.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  \
# 0                    13               negative
# 1                    17               negative
# 2                     8               negative
# 3                     5               negative
# 4                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# ...

# %%
df['SARS-Cov-2 exam result'].value_counts()
# Out:
# negative    5086
# positive     558
# Name: SARS-Cov-2 exam result, dtype: int64
